# %% [markdown]
# # Introduction to Data Science

# %% [markdown]
# ## What Libraries?

# %% [markdown]
# #### Pandas is a package in Python that helps to handle lots of data. It helps to sort and clean the data.
#
#
# > From Pands documentation: https://pypi.org/project/pandas/
#
# ##### Some highlights:
#
# - Easy handling of **missing data** (represented as NaN) in floating point as well as non-floating point data
# - Size mutability: columns can be **inserted and deleted** from DataFrame and higher dimensional objects
# - Intelligent **label-based slicing**, **fancy indexing**, and **subsetting** of large data sets
# - Intuitive **merging** and **joining** data sets
# - Flexible **reshaping** and **pivoting** of data sets
#
#
# #### Numpy is a package that defines a multi-dimensional array object.
#
# > From Numpy documentation: https://pypi.org/project/numpy/
#
#
# #### maplotlib produces quality 2D graphics
#
# > From matplotlib documentation: https://pypi.org/project/matplotlib/
#
# #### seaborn is a library for making statistical graphics
#
# > From seaborn documentation: https://pypi.org/project/seaborn/
#
# Let's get started with a sample data

# %%
import pandas as pd # the pd is by convention
import numpy as np # as is the np

import matplotlib.pyplot as plt
import seaborn as sns

# To Plot matplotlib figures inline on the notebook
# %matplotlib inline

# %% [markdown]
# A Dataframe is essentially a table, like shown below

# %% [markdown]
# ### Reading Data
#
# Data Description:
#
# Impaired Driving Death Rate, by Age and Gender, 2012, Region 5 - Chicago
# Rate of deaths by age/gender (per 100,000 population) for people killed in crashes involving a driver with BAC (blood alcohol concentration) =0.08%
#
# Data obtained from data.gov
# https://catalog.data.gov/dataset/impaired-driving-death-rate-by-age-and-gender-2012-region-5-chicago

# %% [markdown]
# ##### To begin with, we're going to read in some data from a CSV

# %%
sample = pd.read_csv("./data/Impaired_Driving_Death_Rate__by_Age_and_Gender__2012___2014__Region_5_-_Chicago.csv")
sample.head()
# Out:
#            State  All Ages, 2012  Ages 0-20, 2012  Ages 21-34, 2012  \
# 0  United States             3.3              1.3               6.7
# 1       Illinois             2.5              0.7               6.0
# 2        Indiana             3.6              1.2               7.2
# 3       Michigan             2.7              1.1               6.8
# 4      Minnesota             2.1              NaN               3.7
#
#    Ages 35+, 2012  Male, 2012  Female, 2012  \
# 0             3.1         5.2           1.5
# 1             2.1         4.0           1.0
# 2             3.5         6.0           1.3
# 3             2.0         4.3           1.2
# 4             2.2         3.2           1.2
#
#                                             Location  All Ages, 2014  \
# 0  United States\n(39.759995942000046, -98.499998...             3.1
# 1  Illinois\n(40.48501223300008, -88.99770922699997)             2.4
# 2  Indiana\n(39.766913353000064, -86.14995646699998)             3.2
# 3  Michigan\n(44.66132238800003, -84.71438555599997)             2.2
# 4  Minnesota\n(46.35564896600005, -94.79419983199...             1.9
#
#    Ages 0-20, 2014  Ages 21-34, 2014  Ages 35+, 2014  Male, 2014  Female, 2014
# 0              1.2               6.2             3.0         4.9           1.4
# 1              0.7               5.5             2.2         3.7           1.3
# 2              NaN               6.3             3.2         5.1           1.3
# 3              1.0               5.1             1.8         3.3           1.1
# 4              NaN               3.5             2.1         3.0           0.9

# %%
sample
# Out:
#            State  All Ages, 2012  Ages 0-20, 2012  Ages 21-34, 2012  \
# 0  United States             3.3              1.3               6.7
# 1       Illinois             2.5              0.7               6.0
# 2        Indiana             3.6              1.2               7.2
# 3       Michigan             2.7              1.1               6.8
# 4      Minnesota             2.1              NaN               3.7
# 5           Ohio             3.5              1.2               6.8
# 6      Wisconsin             3.6              1.6               6.5
#
#    Ages 35+, 2012  Male, 2012  Female, 2012  \
# 0             3.1         5.2           1.5
# 1             2.1         4.0           1.0
# 2             3.5         6.0           1.3
# 3             2.0         4.3           1.2
# 4             2.2         3.2           1.2
# 5             3.3         5.5           1.6
# 6             3.5         5.6           1.6
#
#                                             Location  All Ages, 2014  \
# 0  United States\n(39.759995942000046, -98.499998...             3.1
# 1  Illinois\n(40.48501223300008, -88.99770922699997)             2.4
# 2  Indiana\n(39.766913353000064, -86.14995646699998)             3.2
# 3  Michigan\n(44.66132238800003, -84.71438555599997)             2.2
# 4  Minnesota\n(46.35564896600005, -94.79419983199...             1.9
# 5     Ohio\n(40.060212455000055, -82.40425667899996)             2.7
# 6  Wisconsin\n(44.39319064600005, -89.81636640199...             2.9
#
#    Ages 0-20, 2014  Ages 21-34, 2014  Ages 35+, 2014  Male, 2014  Female, 2014
# 0              1.2               6.2             3.0         4.9           1.4
# 1              0.7               5.5             2.2         3.7           1.3
# 2              NaN               6.3             3.2         5.1           1.3
# 3              1.0               5.1             1.8         3.3           1.1
# 4              NaN               3.5             2.1         3.0           0.9
# 5              0.8               5.6             2.6         4.2           1.3
# 6              NaN               7.5             2.3         4.8           1.2

# %%
sample.tail()
# Out:
#        State  All Ages, 2012  Ages 0-20, 2012  Ages 21-34, 2012  \
# 2    Indiana             3.6              1.2               7.2
# 3   Michigan             2.7              1.1               6.8
# 4  Minnesota             2.1              NaN               3.7
# 5       Ohio             3.5              1.2               6.8
# 6  Wisconsin             3.6              1.6               6.5
#
#    Ages 35+, 2012  Male, 2012  Female, 2012  \
# 2             3.5         6.0           1.3
# 3             2.0         4.3           1.2
# 4             2.2         3.2           1.2
# 5             3.3         5.5           1.6
# 6             3.5         5.6           1.6
#
#                                             Location  All Ages, 2014  \
# 2  Indiana\n(39.766913353000064, -86.14995646699998)             3.2
# 3  Michigan\n(44.66132238800003, -84.71438555599997)             2.2
# 4  Minnesota\n(46.35564896600005, -94.79419983199...             1.9
# 5     Ohio\n(40.060212455000055, -82.40425667899996)             2.7
# 6  Wisconsin\n(44.39319064600005, -89.81636640199...             2.9
#
#    Ages 0-20, 2014  Ages 21-34, 2014  Ages 35+, 2014  Male, 2014  Female, 2014
# 2              NaN               6.3             3.2         5.1           1.3
# 3              1.0               5.1             1.8         3.3           1.1
# 4              NaN               3.5             2.1         3.0           0.9
# 5              0.8               5.6             2.6         4.2           1.3
# 6              NaN               7.5             2.3         4.8           1.2

# %% [markdown]
# Let's use a Pandas built-in function to learn more about our data.

# %%
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 14 columns):
# State               7 non-null object
# All Ages, 2012      7 non-null float64
# Ages 0-20, 2012     6 non-null float64
# Ages 21-34, 2012    7 non-null float64
# Ages 35+, 2012      7 non-null float64
# Male, 2012          7 non-null float64
# Female, 2012        7 non-null float64
# Location            7 non-null object
# All Ages, 2014      7 non-null float64
# Ages 0-20, 2014     4 non-null float64
# Ages 21-34, 2014    7 non-null float64
# Ages 35+, 2014      7 non-null float64
# Male, 2014          7 non-null float64
# Female, 2014        7 non-null float64
# dtypes: float64(12), object(2)
# memory usage: 864.0+ bytes

# %%
sample.describe()
# Out:
#        All Ages, 2012  Ages 0-20, 2012  Ages 21-34, 2012  Ages 35+, 2012  \
# count        7.000000         6.000000          7.000000        7.000000
# mean         3.042857         1.183333          6.242857        2.814286
# std          0.605137         0.292689          1.178781        0.684175
# min          2.100000         0.700000          3.700000        2.000000
# 25%          2.600000         1.125000          6.250000        2.150000
# 50%          3.300000         1.200000          6.700000        3.100000
# 75%          3.550000         1.275000          6.800000        3.400000
# max          3.600000         1.600000          7.200000        3.500000
#
#        Male, 2012  Female, 2012  All Ages, 2014  Ages 0-20, 2014  \
# count    7.000000      7.000000        7.000000         4.000000
# mean     4.828571      1.342857        2.628571         0.925000
# std      1.014420      0.229907        0.482059         0.221736
# min      3.200000      1.000000        1.900000         0.700000
# 25%      4.150000      1.200000        2.300000         0.775000
# 50%      5.200000      1.300000        2.700000         0.900000
# 75%      5.550000      1.550000        3.000000         1.050000
# max      6.000000      1.600000        3.200000         1.200000
#
#        Ages 21-34, 2014  Ages 35+, 2014  Male, 2014  Female, 2014
# count          7.000000        7.000000    7.000000      7.000000
# mean           5.671429        2.457143    4.142857      1.214286
# std            1.231143        0.502849    0.830376      0.167616
# min            3.500000        1.800000    3.000000      0.900000
# 25%            5.300000        2.150000    3.500000      1.150000
# 50%            5.600000        2.300000    4.200000      1.300000
# 75%            6.250000        2.800000    4.850000      1.300000
# max            7.500000        3.200000    5.100000      1.400000

# %%
sample.shape
# Out:
# (7, 14)

# %% [markdown]
# Great, looks like these are all behaving relatively as expected! That's lovely.

# %% [markdown]
# ### Getting data from the dataframe
#
# Now let's learn how to grab some data from the DataFrame.

# %%
sample['All Ages, 2012'].head()
# Out:
# 0    3.3
# 1    2.5
# 2    3.6
# 3    2.7
# 4    2.1
# Name: All Ages, 2012, dtype: float64

# %%
sample['All Ages, 2012']
# Out:
# 0    3.3
# 1    2.5
# 2    3.6
# 3    2.7
# 4    2.1
# 5    3.5
# 6    3.6
# Name: All Ages, 2012, dtype: float64

# %%
sample['All Ages, 2012'].value_counts()
# Out:
# 3.6    2
# 2.7    1
# 3.3    1
# 2.1    1
# 3.5    1
# 2.5    1
# Name: All Ages, 2012, dtype: int64

# %% [markdown]
# **Exercise 1:**
#
# Using the dataframe, figure out what the lowest death rate state is (for all ages, 2012)

# %%
sample.columns
# Out:
# Index(['State', 'All Ages, 2012', 'Ages 0-20, 2012', 'Ages 21-34, 2012',
#        'Ages 35+, 2012', 'Male, 2012', 'Female, 2012', 'Location',
#        'All Ages, 2014', 'Ages 0-20, 2014', 'Ages 21-34, 2014',
#        'Ages 35+, 2014', 'Male, 2014', 'Female, 2014'],
#       dtype='object')

# %%
sample.groupby(['State', 'All Ages, 2012']).size()
# Out:
# State          All Ages, 2012
# Illinois       2.5               1
# Indiana        3.6               1
# Michigan       2.7               1
# Minnesota      2.1               1
# Ohio           3.5               1
# United States  3.3               1
# Wisconsin      3.6               1
# dtype: int64

# %%
# Subsetting
newsample=sample[['State', 'All Ages, 2012']]
newsample
# Out:
#            State  All Ages, 2012
# 0  United States             3.3
# 1       Illinois             2.5
# 2        Indiana             3.6
# 3       Michigan             2.7
# 4      Minnesota             2.1
# 5           Ohio             3.5
# 6      Wisconsin             3.6

# %% [markdown]
# We'll use `.idxmin` to do the job. It will return the first occurrence of minimum value

# %%
newsample.loc[newsample['All Ages, 2012'].idxmin()]
# Out:
# State             Minnesota
# All Ages, 2012          2.1
# Name: 4, dtype: object

# %% [markdown]
# ### Row Lookups

# %% [markdown]
# We'll use `.iloc` to do the job. Let's demonstrate by grabbing the first (0th) row.

# %%
newsample.iloc[0]
# Out:
# State             United States
# All Ages, 2012              3.3
# Name: 0, dtype: object

# %%
sample.iloc[0]
# Out:
# State                                                   United States
# All Ages, 2012                                                    3.3
# Ages 0-20, 2012                                                   1.3
# Ages 21-34, 2012                                                  6.7
# Ages 35+, 2012                                                    3.1
# Male, 2012                                                        5.2
# Female, 2012                                                      1.5
# Location            United States\n(39.759995942000046, -98.499998...
# All Ages, 2014                                                    3.1
# Ages 0-20, 2014                                                   1.2
# Ages 21-34, 2014                                                  6.2
# Ages 35+, 2014                                                      3
# Male, 2014                                                        4.9
# Female, 2014                                                      1.4
# Name: 0, dtype: object

# %% [markdown]
# return multiple rows by following Python's conventions like so:

# %%
newsample.iloc[0:3]
# Out:
#            State  All Ages, 2012
# 0  United States             3.3
# 1       Illinois             2.5
# 2        Indiana             3.6

# %%
sample.iloc[0:3]
# Out:
#            State  All Ages, 2012  Ages 0-20, 2012  Ages 21-34, 2012  \
# 0  United States             3.3              1.3               6.7
# 1       Illinois             2.5              0.7               6.0
# 2        Indiana             3.6              1.2               7.2
#
#    Ages 35+, 2012  Male, 2012  Female, 2012  \
# 0             3.1         5.2           1.5
# 1             2.1         4.0           1.0
# 2             3.5         6.0           1.3
#
#                                             Location  All Ages, 2014  \
# 0  United States\n(39.759995942000046, -98.499998...             3.1
# 1  Illinois\n(40.48501223300008, -88.99770922699997)             2.4
# 2  Indiana\n(39.766913353000064, -86.14995646699998)             3.2
#
#    Ages 0-20, 2014  Ages 21-34, 2014  Ages 35+, 2014  Male, 2014  Female, 2014
# 0              1.2               6.2             3.0         4.9           1.4
# 1              0.7               5.5             2.2         3.7           1.3
# 2              NaN               6.3             3.2         5.1           1.3

# %% [markdown]
# Note:iloc means "index location" ####STOP

# %% [markdown]
# ### Filtering

# %% [markdown]
# Now we want to filter the data so we only see rows that match a certain criteria. If condition criter is met, it will show true and if not, mark it as a false.

# %%
lowerdeath = (sample['All Ages, 2012'] < 3) 
lowerdeath
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# 5    False
# 6    False
# Name: All Ages, 2012, dtype: bool

# %%
sample
# Out:
#            State  All Ages, 2012  Ages 0-20, 2012  Ages 21-34, 2012  \
# 0  United States             3.3              1.3               6.7
# 1       Illinois             2.5              0.7               6.0
# 2        Indiana             3.6              1.2               7.2
# 3       Michigan             2.7              1.1               6.8
# 4      Minnesota             2.1              NaN               3.7
# 5           Ohio             3.5              1.2               6.8
# 6      Wisconsin             3.6              1.6               6.5
#
#    Ages 35+, 2012  Male, 2012  Female, 2012  \
# 0             3.1         5.2           1.5
# 1             2.1         4.0           1.0
# 2             3.5         6.0           1.3
# 3             2.0         4.3           1.2
# 4             2.2         3.2           1.2
# 5             3.3         5.5           1.6
# 6             3.5         5.6           1.6
#
#                                             Location  All Ages, 2014  \
# 0  United States\n(39.759995942000046, -98.499998...             3.1
# 1  Illinois\n(40.48501223300008, -88.99770922699997)             2.4
# 2  Indiana\n(39.766913353000064, -86.14995646699998)             3.2
# 3  Michigan\n(44.66132238800003, -84.71438555599997)             2.2
# 4  Minnesota\n(46.35564896600005, -94.79419983199...             1.9
# 5     Ohio\n(40.060212455000055, -82.40425667899996)             2.7
# 6  Wisconsin\n(44.39319064600005, -89.81636640199...             2.9
#
#    Ages 0-20, 2014  Ages 21-34, 2014  Ages 35+, 2014  Male, 2014  Female, 2014
# 0              1.2               6.2             3.0         4.9           1.4
# 1              0.7               5.5             2.2         3.7           1.3
# 2              NaN               6.3             3.2         5.1           1.3
# 3              1.0               5.1             1.8         3.3           1.1
# 4              NaN               3.5             2.1         3.0           0.9
# 5              0.8               5.6             2.6         4.2           1.3
# 6              NaN               7.5             2.3         4.8           1.2

# %%
lowerdeathM = (sample['Male, 2012'] < 5) 
lowerdeathM
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# 5    False
# 6    False
# Name: Male, 2012, dtype: bool

# %% [markdown]
# Now we apply the lower death and should see that only rows with that condition!

# %%
sample_test = sample[lowerdeath] 
sample_test
#sample_test.head()
# Out:
#        State  All Ages, 2012  Ages 0-20, 2012  Ages 21-34, 2012  \
# 1   Illinois             2.5              0.7               6.0
# 3   Michigan             2.7              1.1               6.8
# 4  Minnesota             2.1              NaN               3.7
#
#    Ages 35+, 2012  Male, 2012  Female, 2012  \
# 1             2.1         4.0           1.0
# 3             2.0         4.3           1.2
# 4             2.2         3.2           1.2
#
#                                             Location  All Ages, 2014  \
# 1  Illinois\n(40.48501223300008, -88.99770922699997)             2.4
# 3  Michigan\n(44.66132238800003, -84.71438555599997)             2.2
# 4  Minnesota\n(46.35564896600005, -94.79419983199...             1.9
#
#    Ages 0-20, 2014  Ages 21-34, 2014  Ages 35+, 2014  Male, 2014  Female, 2014
# 1              0.7               5.5             2.2         3.7           1.3
# 3              1.0               5.1             1.8         3.3           1.1
# 4              NaN               3.5             2.1         3.0           0.9

# %% [markdown]
# Multiple condition? no issues

# %%
test = (sample['Female, 2012'] == 1.0) & (sample['All Ages, 2012'] == 2.5)
sample[test]
# Out:
#       State  All Ages, 2012  Ages 0-20, 2012  Ages 21-34, 2012  \
# 1  Illinois             2.5              0.7               6.0
#
#    Ages 35+, 2012  Male, 2012  Female, 2012  \
# 1             2.1         4.0           1.0
#
#                                             Location  All Ages, 2014  \
# 1  Illinois\n(40.48501223300008, -88.99770922699997)             2.4
#
#    Ages 0-20, 2014  Ages 21-34, 2014  Ages 35+, 2014  Male, 2014  Female, 2014
# 1              0.7               5.5             2.2         3.7           1.3

# %% [markdown]
# **Exercise 2:**
#
# Apply a new filter to select lowest death for all ages in 2014

# %%
# Hint: create a filter called mask, then apply it to the dataframe

# %%
# Subsetting
newsample=sample[['State', 'All Ages, 2014']]
newsample
# Out:
#            State  All Ages, 2014
# 0  United States             3.1
# 1       Illinois             2.4
# 2        Indiana             3.2
# 3       Michigan             2.2
# 4      Minnesota             1.9
# 5           Ohio             2.7
# 6      Wisconsin             2.9

# %%
newsample.loc[newsample['All Ages, 2014'].idxmin()]
# Out:
# State             Minnesota
# All Ages, 2014          1.9
# Name: 4, dtype: object

# %% [markdown]
# ### Doing Stats with Pandas

# %% [markdown]
# Let's do some summary statistics

# %%
sample['All Ages, 2012'].mean()
# Out:
# 3.0428571428571436

# %% [markdown]
# Or we could find the max or min

# %%
print(sample['All Ages, 2012'].max())
# Out:
# 3.6

# %%
print(sample['All Ages, 2012'].min())
# Out:
# 2.1

# %% [markdown]
# ### Making new columns

# %% [markdown]
# Pandas also allows us to create columns that are mixtures of other columns. Let's make a column that is "visibility as a percentage of the maximum visibility".

# %%
sample.head(3)
# Out:
#            State  All Ages, 2012  Ages 0-20, 2012  Ages 21-34, 2012  \
# 0  United States             3.3              1.3               6.7
# 1       Illinois             2.5              0.7               6.0
# 2        Indiana             3.6              1.2               7.2
#
#    Ages 35+, 2012  Male, 2012  Female, 2012  \
# 0             3.1         5.2           1.5
# 1             2.1         4.0           1.0
# 2             3.5         6.0           1.3
#
#                                             Location  All Ages, 2014  \
# 0  United States\n(39.759995942000046, -98.499998...             3.1
# 1  Illinois\n(40.48501223300008, -88.99770922699997)             2.4
# 2  Indiana\n(39.766913353000064, -86.14995646699998)             3.2
#
#    Ages 0-20, 2014  Ages 21-34, 2014  Ages 35+, 2014  Male, 2014  Female, 2014
# 0              1.2               6.2             3.0         4.9           1.4
# 1              0.7               5.5             2.2         3.7           1.3
# 2              NaN               6.3             3.2         5.1           1.3

# %%
#drop rows
newdf=sample[1:6]
newdf
# Out:
#        State  All Ages, 2012  Ages 0-20, 2012  Ages 21-34, 2012  \
# 1   Illinois             2.5              0.7               6.0
# 2    Indiana             3.6              1.2               7.2
# 3   Michigan             2.7              1.1               6.8
# 4  Minnesota             2.1              NaN               3.7
# 5       Ohio             3.5              1.2               6.8
#
#    Ages 35+, 2012  Male, 2012  Female, 2012  \
# 1             2.1         4.0           1.0
# 2             3.5         6.0           1.3
# 3             2.0         4.3           1.2
# 4             2.2         3.2           1.2
# 5             3.3         5.5           1.6
#
#                                             Location  All Ages, 2014  \
# 1  Illinois\n(40.48501223300008, -88.99770922699997)             2.4
# 2  Indiana\n(39.766913353000064, -86.14995646699998)             3.2
# 3  Michigan\n(44.66132238800003, -84.71438555599997)             2.2
# 4  Minnesota\n(46.35564896600005, -94.79419983199...             1.9
# 5     Ohio\n(40.060212455000055, -82.40425667899996)             2.7
#
#    Ages 0-20, 2014  Ages 21-34, 2014  Ages 35+, 2014  Male, 2014  Female, 2014
# 1              0.7               5.5             2.2         3.7           1.3
# 2              NaN               6.3             3.2         5.1           1.3
# 3              1.0               5.1             1.8         3.3           1.1
# 4              NaN               3.5             2.1         3.0           0.9
# 5              0.8               5.6             2.6         4.2           1.3

# %%
#drop columns
newdf2=sample.drop(columns=["State"])
newdf2
# Out:
#    All Ages, 2012  Ages 0-20, 2012  Ages 21-34, 2012  Ages 35+, 2012  \
# 0             3.3              1.3               6.7             3.1
# 1             2.5              0.7               6.0             2.1
# 2             3.6              1.2               7.2             3.5
# 3             2.7              1.1               6.8             2.0
# 4             2.1              NaN               3.7             2.2
# 5             3.5              1.2               6.8             3.3
# 6             3.6              1.6               6.5             3.5
#
#    Male, 2012  Female, 2012  \
# 0         5.2           1.5
# 1         4.0           1.0
# 2         6.0           1.3
# 3         4.3           1.2
# 4         3.2           1.2
# 5         5.5           1.6
# 6         5.6           1.6
#
#                                             Location  All Ages, 2014  \
# 0  United States\n(39.759995942000046, -98.499998...             3.1
# 1  Illinois\n(40.48501223300008, -88.99770922699997)             2.4
# 2  Indiana\n(39.766913353000064, -86.14995646699998)             3.2
# 3  Michigan\n(44.66132238800003, -84.71438555599997)             2.2
# 4  Minnesota\n(46.35564896600005, -94.79419983199...             1.9
# 5     Ohio\n(40.060212455000055, -82.40425667899996)             2.7
# 6  Wisconsin\n(44.39319064600005, -89.81636640199...             2.9
#
#    Ages 0-20, 2014  Ages 21-34, 2014  Ages 35+, 2014  Male, 2014  Female, 2014
# 0              1.2               6.2             3.0         4.9           1.4
# 1              0.7               5.5             2.2         3.7           1.3
# 2              NaN               6.3             3.2         5.1           1.3
# 3              1.0               5.1             1.8         3.3           1.1
# 4              NaN               3.5             2.1         3.0           0.9
# 5              0.8               5.6             2.6         4.2           1.3
# 6              NaN               7.5             2.3         4.8           1.2

# %%
sample['compare_two deaths_all ages'] = sample['All Ages, 2012']-sample['All Ages, 2014']
sample
# Out:
#            State  All Ages, 2012  Ages 0-20, 2012  Ages 21-34, 2012  \
# 0  United States             3.3              1.3               6.7
# 1       Illinois             2.5              0.7               6.0
# 2        Indiana             3.6              1.2               7.2
# 3       Michigan             2.7              1.1               6.8
# 4      Minnesota             2.1              NaN               3.7
# 5           Ohio             3.5              1.2               6.8
# 6      Wisconsin             3.6              1.6               6.5
#
#    Ages 35+, 2012  Male, 2012  Female, 2012  \
# 0             3.1         5.2           1.5
# 1             2.1         4.0           1.0
# 2             3.5         6.0           1.3
# 3             2.0         4.3           1.2
# 4             2.2         3.2           1.2
# 5             3.3         5.5           1.6
# 6             3.5         5.6           1.6
#
#                                             Location  All Ages, 2014  \
# 0  United States\n(39.759995942000046, -98.499998...             3.1
# 1  Illinois\n(40.48501223300008, -88.99770922699997)             2.4
# 2  Indiana\n(39.766913353000064, -86.14995646699998)             3.2
# 3  Michigan\n(44.66132238800003, -84.71438555599997)             2.2
# 4  Minnesota\n(46.35564896600005, -94.79419983199...             1.9
# 5     Ohio\n(40.060212455000055, -82.40425667899996)             2.7
# 6  Wisconsin\n(44.39319064600005, -89.81636640199...             2.9
#
#    Ages 0-20, 2014  Ages 21-34, 2014  Ages 35+, 2014  Male, 2014  \
# 0              1.2               6.2             3.0         4.9
# 1              0.7               5.5             2.2         3.7
# 2              NaN               6.3             3.2         5.1
# 3              1.0               5.1             1.8         3.3
# 4              NaN               3.5             2.1         3.0
# 5              0.8               5.6             2.6         4.2
# 6              NaN               7.5             2.3         4.8
#
#    Female, 2014  compare_two deaths_all ages
# 0           1.4                          0.2
# 1           1.3                          0.1
# 2           1.3                          0.4
# 3           1.1                          0.5
# 4           0.9                          0.2
# 5           1.3                          0.8
# 6           1.2                          0.7

# %%
##check nulls in the data

sample.isnull().sum()
# Out:
# State                          0
# All Ages, 2012                 0
# Ages 0-20, 2012                1
# Ages 21-34, 2012               0
# Ages 35+, 2012                 0
# Male, 2012                     0
# Female, 2012                   0
# Location                       0
# All Ages, 2014                 0
# Ages 0-20, 2014                3
# Ages 21-34, 2014               0
# Ages 35+, 2014                 0
# Male, 2014                     0
# Female, 2014                   0
# compare_two deaths_all ages    0
# dtype: int64

# %%
#map missing values

sns.heatmap(sample.isnull(), cbar=False)

# %% [markdown]
# ### Plotting with Pandas

# %% [markdown]
# The last part of pandas we want to explore today is some of it's built in plotting features. let's plot histogram

# %%
sample['All Ages, 2012'].plot.hist()
plt.xlabel("Death rate for All Ages, 2012");

# %% [markdown]
# **Exercise 3**
#
# Plot a histogram of other columns e.g. 'All Ages, 2012'

# %%
# Hint: plot.hist(), plot.line()

# %%
sample['All Ages, 2014'].plot.hist()
plt.xlabel("Death rate for All Ages, 2014");

# %%
new_sample=sample[['All Ages, 2012',
       'Ages 0-20, 2012', 'Ages 21-34, 2012', 'Ages 35+, 2012',
        'Male, 2012', 
        'Female, 2012']]

# %%
new_sample
# Out:
#    All Ages, 2012  Ages 0-20, 2012  Ages 21-34, 2012  Ages 35+, 2012  \
# 0             3.3              1.3               6.7             3.1
# 1             2.5              0.7               6.0             2.1
# 2             3.6              1.2               7.2             3.5
# 3             2.7              1.1               6.8             2.0
# 4             2.1              NaN               3.7             2.2
# 5             3.5              1.2               6.8             3.3
# 6             3.6              1.6               6.5             3.5
#
#    Male, 2012  Female, 2012
# 0         5.2           1.5
# 1         4.0           1.0
# 2         6.0           1.3
# 3         4.3           1.2
# 4         3.2           1.2
# 5         5.5           1.6
# 6         5.6           1.6

# %% [markdown]
# ### Plotting with matplotlib

# %%
x = new_sample['Female, 2012']
y = new_sample['Male, 2012']

plt.scatter(x, y,  alpha=0.5)
plt.show()

# %% [markdown]
# ## Correlation Analysis

# %%
new_sample.corr()
# Out:
#                   All Ages, 2012  Ages 0-20, 2012  Ages 21-34, 2012  \
# All Ages, 2012          1.000000         0.808639          0.791399
# Ages 0-20, 2012         0.808639         1.000000          0.440302
# Ages 21-34, 2012        0.791399         0.440302          1.000000
# Ages 35+, 2012          0.928183         0.746299          0.519888
# Male, 2012              0.991380         0.731329          0.823930
# Female, 2012            0.775253         0.865157          0.373383
#
#                   Ages 35+, 2012  Male, 2012  Female, 2012
# All Ages, 2012          0.928183    0.991380      0.775253
# Ages 0-20, 2012         0.746299    0.731329      0.865157
# Ages 21-34, 2012        0.519888    0.823930      0.373383
# Ages 35+, 2012          1.000000    0.909443      0.811328
# Male, 2012              0.909443    1.000000      0.694209
# Female, 2012            0.811328    0.694209      1.000000

# %% [markdown]
# ### Correlation matrix with seaborn

# %%
Var_Corr = new_sample.corr()
sns.heatmap(Var_Corr, xticklabels=Var_Corr.columns, yticklabels=Var_Corr.columns, annot=True)

# %%
def heatMap(df):
    corr = new_sample.corr()
    fig, ax = plt.subplots(figsize=(10, 10))
    colormap = sns.diverging_palette(220, 10, as_cmap=True)
    sns.heatmap(corr, cmap=colormap, annot=True, fmt=".2f")
    plt.xticks(range(len(corr.columns)), corr.columns);
    plt.yticks(range(len(corr.columns)), corr.columns)
    plt.show()

# %%
heatMap(new_sample)

# %%
pd.plotting.scatter_matrix(new_sample, figsize=(10, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12d0ece48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d12eb38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d14d9e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d16eeb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d19c588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d19c5c0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12d1f52e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d21e978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d251048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d2776d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d2a1d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d2d3438>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12d2fbac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d32b198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12bf00780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d37c6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d3a6d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d3d9400>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12d3ffa90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d432160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d4597f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d480e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d4b2550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d4dabe0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12d50b2b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d537940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d55efd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d5906a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d5b8d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d5e9400>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12d611a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d643160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d66b7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d693e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d6c5550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d6edbe0>]],
#       dtype=object)

# %% [markdown]
# ## Challenges

# %% [markdown]
# In the data folder, there is a csv that contains the file `Census_Data_-_Selected_socioeconomic_indicators_in_Chicago__2008___2012.csv`. That data is from here: https://catalog.data.gov/dataset/census-data-selected-socioeconomic-indicators-in-chicago-2008-2012-36e55
#
# This dataset contains a selection of six socioeconomic indicators of public health significance and a “hardship index,” by Chicago community area, for the years 2008 – 2012. The indicators are the percent of occupied housing units with more than one person per room (i.e., crowded housing); the percent of households living below the federal poverty level; the percent of persons in the labor force over the age of 16 years that are unemployed; the percent of persons over the age of 25 years without a high school diploma; the percent of the population under 18 or over 64 years of age (i.e., dependency); and per capita income.

# %% [markdown]
# ### Challenge 1: Load the file into a Pandas dataframe, then print the top 5 rows
#
# Store this dataframe in a variable called `poverty`

# %%
poverty = pd.read_csv("./data/Census_Data_-_Selected_socioeconomic_indicators_in_Chicago__2008___2012.csv")
poverty.head()
# Out:
#    Community Area Number COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 0                    1.0         Rogers Park                         7.7
# 1                    2.0          West Ridge                         7.8
# 2                    3.0              Uptown                         3.8
# 3                    4.0      Lincoln Square                         3.4
# 4                    5.0        North Center                         0.3
#
#    PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 0                              23.6                          8.7
# 1                              17.2                          8.8
# 2                              24.0                          8.9
# 3                              10.9                          8.2
# 4                               7.5                          5.2
#
#    PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 0                                          18.2
# 1                                          20.8
# 2                                          11.8
# 3                                          13.4
# 4                                           4.5
#
#    PERCENT AGED UNDER 18 OR OVER 64  PER CAPITA INCOME  HARDSHIP INDEX
# 0                              27.5              23939            39.0
# 1                              38.5              23040            46.0
# 2                              22.2              35787            20.0
# 3                              25.5              37524            17.0
# 4                              26.2              57123             6.0

# %% [markdown]
# ### Challenge 2: Find the mean 'PER CAPITA INCOME' and the mean 'PERCENT AGED 16+ UNEMPLOYED' in the dataset as a whole.

# %%
poverty.describe()
# Out:
#        Community Area Number  PERCENT OF HOUSING CROWDED  \
# count              77.000000                   78.000000
# mean               39.000000                    4.920513
# std                22.371857                    3.658981
# min                 1.000000                    0.300000
# 25%                20.000000                    2.325000
# 50%                39.000000                    3.850000
# 75%                58.000000                    6.800000
# max                77.000000                   15.800000
#
#        PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# count                         78.000000                    78.000000
# mean                          21.739744                    15.341026
# std                           11.457231                     7.499497
# min                            3.300000                     4.700000
# 25%                           13.350000                     9.200000
# 50%                           19.050000                    13.850000
# 75%                           29.150000                    20.000000
# max                           56.500000                    35.900000
#
#        PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# count                                     78.000000
# mean                                      20.330769
# std                                       11.746514
# min                                        2.500000
# 25%                                       12.075000
# 50%                                       18.650000
# 75%                                       26.600000
# max                                       54.800000
#
#        PERCENT AGED UNDER 18 OR OVER 64  PER CAPITA INCOME  HARDSHIP INDEX
# count                         78.000000          78.000000       77.000000
# mean                          35.717949       25597.000000       49.506494
# std                            7.284421       15196.405541       28.690556
# min                           13.500000        8201.000000        1.000000
# 25%                           32.150000       15804.750000       25.000000
# 50%                           38.050000       21668.500000       50.000000
# 75%                           40.500000       28715.750000       74.000000
# max                           51.500000       88669.000000       98.000000

# %%
poverty['PER CAPITA INCOME'].mean()
# Out:
# 25597.0

# %%
poverty['PERCENT AGED 16+ UNEMPLOYED'].mean()
# Out:
# 15.341025641025643

# %% [markdown]
# ### Challenge 3: Find max, min and mean of 'HARDSHIP INDEX' and return name of 'COMMUNITY AREA NAME'

# %%
poverty.describe()
# Out:
#        Community Area Number  PERCENT OF HOUSING CROWDED  \
# count              77.000000                   78.000000
# mean               39.000000                    4.920513
# std                22.371857                    3.658981
# min                 1.000000                    0.300000
# 25%                20.000000                    2.325000
# 50%                39.000000                    3.850000
# 75%                58.000000                    6.800000
# max                77.000000                   15.800000
#
#        PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# count                         78.000000                    78.000000
# mean                          21.739744                    15.341026
# std                           11.457231                     7.499497
# min                            3.300000                     4.700000
# 25%                           13.350000                     9.200000
# 50%                           19.050000                    13.850000
# 75%                           29.150000                    20.000000
# max                           56.500000                    35.900000
#
#        PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# count                                     78.000000
# mean                                      20.330769
# std                                       11.746514
# min                                        2.500000
# 25%                                       12.075000
# 50%                                       18.650000
# 75%                                       26.600000
# max                                       54.800000
#
#        PERCENT AGED UNDER 18 OR OVER 64  PER CAPITA INCOME  HARDSHIP INDEX
# count                         78.000000          78.000000       77.000000
# mean                          35.717949       25597.000000       49.506494
# std                            7.284421       15196.405541       28.690556
# min                           13.500000        8201.000000        1.000000
# 25%                           32.150000       15804.750000       25.000000
# 50%                           38.050000       21668.500000       50.000000
# 75%                           40.500000       28715.750000       74.000000
# max                           51.500000       88669.000000       98.000000

# %%
ndf=poverty[['COMMUNITY AREA NAME', 'HARDSHIP INDEX']]

# %%
ndf.loc[ndf['HARDSHIP INDEX'].idxmin()]
# Out:
# COMMUNITY AREA NAME    Near North Side
# HARDSHIP INDEX                       1
# Name: 7, dtype: object

# %%
ndf.loc[ndf['HARDSHIP INDEX'].idxmax()]
# Out:
# COMMUNITY AREA NAME    Riverdale
# HARDSHIP INDEX                98
# Name: 53, dtype: object

# %% [markdown]
# ### Challenge 4: Plot a histogram for 'HARDSHIP INDEX'

# %%
poverty['HARDSHIP INDEX'].plot.hist()
plt.xlabel("Hardship index score");

# %% [markdown]
# ### Challenge 5: Create new column 'New HARDSHIP INDEX' by calculating 'HARDSHIP INDEX'/Mean of 'HARDSHIP INDEX'

# %%
poverty['New HARDSHIP INDEX'] = poverty['HARDSHIP INDEX']/poverty['HARDSHIP INDEX'].mean()
poverty
# Out:
#     Community Area Number     COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 0                     1.0             Rogers Park                         7.7
# 1                     2.0              West Ridge                         7.8
# 2                     3.0                  Uptown                         3.8
# 3                     4.0          Lincoln Square                         3.4
# 4                     5.0            North Center                         0.3
# 5                     6.0               Lake View                         1.1
# 6                     7.0            Lincoln Park                         0.8
# 7                     8.0         Near North Side                         1.9
# 8                     9.0             Edison Park                         1.1
# 9                    10.0            Norwood Park                         2.0
# 10                   11.0          Jefferson Park                         2.7
# 11                   12.0             Forest Glen                         1.1
# 12                   13.0              North Park                         3.9
# 13                   14.0             Albany Park                        11.3
# 14                   15.0            Portage Park                         4.1
# 15                   16.0             Irving Park                         6.3
# 16                   17.0                 Dunning                         5.2
# 17                   18.0              Montclaire                         8.1
# 18                   19.0          Belmont Cragin                        10.8
# 19                   20.0                 Hermosa                         6.9
# 20                   21.0                Avondale                         6.0
# 21                   22.0            Logan Square                         3.2
# 22                   23.0           Humboldt park                        14.8
# 23                   24.0               West Town                         2.3
# 24                   25.0                  Austin                         6.3
# 25                   26.0      West Garfield Park                         9.4
# 26                   27.0      East Garfield Park                         8.2
# 27                   28.0          Near West Side                         3.8
# 28                   29.0          North Lawndale                         7.4
# 29                   30.0          South Lawndale                        15.2
# ..                    ...                     ...                         ...
# 48                   49.0                Roseland                         2.5
# 49                   50.0                 Pullman                         1.5
# 50                   51.0           South Deering                         4.0
# 51                   52.0               East Side                         6.8
# 52                   53.0            West Pullman                         3.3
# 53                   54.0               Riverdale                         5.8
# 54                   55.0               Hegewisch                         3.3
# 55                   56.0          Garfield Ridge                         2.6
# 56                   57.0          Archer Heights                         8.5
# 57                   58.0           Brighton Park                        14.4
# 58                   59.0           McKinley Park                         7.2
# 59                   60.0              Bridgeport                         4.5
# 60                   61.0                New City                        11.9
# 61                   62.0             West Elsdon                        11.1
# 62                   63.0               Gage Park                        15.8
# 63                   64.0                Clearing                         2.7
# 64                   65.0               West Lawn                         5.8
# 65                   66.0            Chicago Lawn                         7.6
# 66                   67.0          West Englewood                         4.8
# 67                   68.0               Englewood                         3.8
# 68                   69.0  Greater Grand Crossing                         3.6
# 69                   70.0                 Ashburn                         4.0
# 70                   71.0          Auburn Gresham                         4.0
# 71                   72.0                 Beverly                         0.9
# 72                   73.0       Washington Height                         1.1
# 73                   74.0         Mount Greenwood                         1.0
# 74                   75.0             Morgan Park                         0.8
# 75                   76.0                  O'Hare                         3.6
# 76                   77.0               Edgewater                         4.1
# 77                    NaN                 CHICAGO                         4.7
#
#     PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 0                               23.6                          8.7
# 1                               17.2                          8.8
# 2                               24.0                          8.9
# 3                               10.9                          8.2
# 4                                7.5                          5.2
# 5                               11.4                          4.7
# 6                               12.3                          5.1
# 7                               12.9                          7.0
# 8                                3.3                          6.5
# 9                                5.4                          9.0
# 10                               8.6                         12.4
# 11                               7.5                          6.8
# 12                              13.2                          9.9
# 13                              19.2                         10.0
# 14                              11.6                         12.6
# 15                              13.1                         10.0
# 16                              10.6                         10.0
# 17                              15.3                         13.8
# 18                              18.7                         14.6
# 19                              20.5                         13.1
# 20                              15.3                          9.2
# 21                              16.8                          8.2
# 22                              33.9                         17.3
# 23                              14.7                          6.6
# 24                              28.6                         22.6
# 25                              41.7                         25.8
# 26                              42.4                         19.6
# 27                              20.6                         10.7
# 28                              43.1                         21.2
# 29                              30.7                         15.8
# ..                               ...                          ...
# 48                              19.8                         20.3
# 49                              21.6                         22.8
# 50                              29.2                         16.3
# 51                              19.2                         12.1
# 52                              25.9                         19.4
# 53                              56.5                         34.6
# 54                              17.1                          9.6
# 55                               8.8                         11.3
# 56                              14.1                         16.5
# 57                              23.6                         13.9
# 58                              18.7                         13.4
# 59                              18.9                         13.7
# 60                              29.0                         23.0
# 61                              15.6                         16.7
# 62                              23.4                         18.2
# 63                               8.9                          9.5
# 64                              14.9                          9.6
# 65                              27.9                         17.1
# 66                              34.4                         35.9
# 67                              46.6                         28.0
# 68                              29.6                         23.0
# 69                              10.4                         11.7
# 70                              27.6                         28.3
# 71                               5.1                          8.0
# 72                              16.9                         20.8
# 73                               3.4                          8.7
# 74                              13.2                         15.0
# 75                              15.4                          7.1
# 76                              18.2                          9.2
# 77                              19.7                         12.9
#
#     PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 0                                           18.2
# 1                                           20.8
# 2                                           11.8
# 3                                           13.4
# 4                                            4.5
# 5                                            2.6
# 6                                            3.6
# 7                                            2.5
# 8                                            7.4
# 9                                           11.5
# 10                                          13.4
# 11                                           4.9
# 12                                          14.4
# 13                                          32.9
# 14                                          19.3
# 15                                          22.4
# 16                                          16.2
# 17                                          23.5
# 18                                          37.3
# 19                                          41.6
# 20                                          24.7
# 21                                          14.8
# 22                                          35.4
# 23                                          12.9
# 24                                          24.4
# 25                                          24.5
# 26                                          21.3
# 27                                           9.6
# 28                                          27.6
# 29                                          54.8
# ..                                           ...
# 48                                          16.9
# 49                                          13.1
# 50                                          21.0
# 51                                          31.9
# 52                                          20.5
# 53                                          27.5
# 54                                          19.2
# 55                                          19.3
# 56                                          35.9
# 57                                          45.1
# 58                                          32.9
# 59                                          22.2
# 60                                          41.5
# 61                                          37.0
# 62                                          51.5
# 63                                          18.8
# 64                                          33.6
# 65                                          31.2
# 66                                          26.3
# 67                                          28.5
# 68                                          16.5
# 69                                          17.7
# 70                                          18.5
# 71                                           3.7
# 72                                          13.7
# 73                                           4.3
# 74                                          10.8
# 75                                          10.9
# 76                                           9.7
# 77                                          19.5
#
#     PERCENT AGED UNDER 18 OR OVER 64  PER CAPITA INCOME  HARDSHIP INDEX  \
# 0                               27.5              23939            39.0
# 1                               38.5              23040            46.0
# 2                               22.2              35787            20.0
# 3                               25.5              37524            17.0
# 4                               26.2              57123             6.0
# 5                               17.0              60058             5.0
# 6                               21.5              71551             2.0
# 7                               22.6              88669             1.0
# 8                               35.3              40959             8.0
# 9                               39.5              32875            21.0
# 10                              35.5              27751            25.0
# 11                              40.5              44164            11.0
# 12                              39.0              26576            33.0
# 13                              32.0              21323            53.0
# 14                              34.0              24336            35.0
# 15                              31.6              27249            34.0
# 16                              33.6              26282            28.0
# 17                              38.6              22014            50.0
# 18                              37.3              15461            70.0
# 19                              36.4              15089            71.0
# 20                              31.0              20039            42.0
# 21                              26.2              31908            23.0
# 22                              38.0              13781            85.0
# 23                              21.7              43198            10.0
# 24                              37.9              15957            73.0
# 25                              43.6              10934            92.0
# 26                              43.2              12961            83.0
# 27                              22.2              44689            15.0
# 28                              42.7              12034            87.0
# 29                              33.8              10402            96.0
# ..                               ...                ...             ...
# 48                              41.2              17949            52.0
# 49                              38.6              20588            51.0
# 50                              39.5              14685            65.0
# 51                              42.8              17104            64.0
# 52                              42.1              16563            62.0
# 53                              51.5               8201            98.0
# 54                              42.9              22677            44.0
# 55                              38.1              26353            32.0
# 56                              39.2              16134            67.0
# 57                              39.3              13089            84.0
# 58                              35.6              16954            61.0
# 59                              31.3              22694            43.0
# 60                              38.9              12765            91.0
# 61                              37.7              15754            69.0
# 62                              38.8              12171            93.0
# 63                              37.6              25113            29.0
# 64                              39.6              16907            56.0
# 65                              40.6              13231            80.0
# 66                              40.7              11317            89.0
# 67                              42.5              11888            94.0
# 68                              41.0              17285            66.0
# 69                              36.9              23482            37.0
# 70                              41.9              15528            74.0
# 71                              40.5              39523            12.0
# 72                              42.6              19713            48.0
# 73                              36.8              34381            16.0
# 74                              40.3              27149            30.0
# 75                              30.3              25828            24.0
# 76                              23.8              33385            19.0
# 77                              33.5              28202             NaN
#
#     New HARDSHIP INDEX
# 0             0.787775
# 1             0.929171
# 2             0.403987
# 3             0.343389
# 4             0.121196
# 5             0.100997
# 6             0.040399
# 7             0.020199
# 8             0.161595
# 9             0.424187
# 10            0.504984
# 11            0.222193
# 12            0.666579
# 13            1.070567
# 14            0.706978
# 15            0.686779
# 16            0.565582
# 17            1.009969
# 18            1.413956
# 19            1.434155
# 20            0.848374
# 21            0.464586
# 22            1.716946
# 23            0.201994
# 24            1.474554
# 25            1.858342
# 26            1.676548
# 27            0.302991
# 28            1.757345
# 29            1.939140
# ..                 ...
# 48            1.050367
# 49            1.030168
# 50            1.312959
# 51            1.292760
# 52            1.252361
# 53            1.979538
# 54            0.888772
# 55            0.646380
# 56            1.353358
# 57            1.696747
# 58            1.232162
# 59            0.868573
# 60            1.838143
# 61            1.393757
# 62            1.878541
# 63            0.585782
# 64            1.131165
# 65            1.615950
# 66            1.797744
# 67            1.898741
# 68            1.333158
# 69            0.747377
# 70            1.494753
# 71            0.242392
# 72            0.969570
# 73            0.323190
# 74            0.605981
# 75            0.484785
# 76            0.383788
# 77                 NaN
#
# [78 rows x 10 columns]

# %% [markdown]
# ### Challenge 6: Identify Null values in the data

# %%
poverty.isnull().sum()
# Out:
# Community Area Number                           1
# COMMUNITY AREA NAME                             0
# PERCENT OF HOUSING CROWDED                      0
# PERCENT HOUSEHOLDS BELOW POVERTY                0
# PERCENT AGED 16+ UNEMPLOYED                     0
# PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA    0
# PERCENT AGED UNDER 18 OR OVER 64                0
# PER CAPITA INCOME                               0
# HARDSHIP INDEX                                  1
# New HARDSHIP INDEX                              1
# dtype: int64

# %% [markdown]
# ### Challenge 7: Subset data into smaller data set, Let's choose 'COMMUNITY AREA NAME', 'PERCENT HOUSEHOLDS BELOW POVERTY', 'PERCENT AGED 16+ UNEMPLOYED', 'PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA', 'PER CAPITA INCOME', and 'HARDSHIP INDEX'

# %%
sub_poverty=poverty[['COMMUNITY AREA NAME',
       'PERCENT HOUSEHOLDS BELOW POVERTY', 'PERCENT AGED 16+ UNEMPLOYED', 'PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA',
        'PER CAPITA INCOME', 
        'HARDSHIP INDEX']]
sub_poverty
# Out:
#        COMMUNITY AREA NAME  PERCENT HOUSEHOLDS BELOW POVERTY  \
# 0              Rogers Park                              23.6
# 1               West Ridge                              17.2
# 2                   Uptown                              24.0
# 3           Lincoln Square                              10.9
# 4             North Center                               7.5
# 5                Lake View                              11.4
# 6             Lincoln Park                              12.3
# 7          Near North Side                              12.9
# 8              Edison Park                               3.3
# 9             Norwood Park                               5.4
# 10          Jefferson Park                               8.6
# 11             Forest Glen                               7.5
# 12              North Park                              13.2
# 13             Albany Park                              19.2
# 14            Portage Park                              11.6
# 15             Irving Park                              13.1
# 16                 Dunning                              10.6
# 17              Montclaire                              15.3
# 18          Belmont Cragin                              18.7
# 19                 Hermosa                              20.5
# 20                Avondale                              15.3
# 21            Logan Square                              16.8
# 22           Humboldt park                              33.9
# 23               West Town                              14.7
# 24                  Austin                              28.6
# 25      West Garfield Park                              41.7
# 26      East Garfield Park                              42.4
# 27          Near West Side                              20.6
# 28          North Lawndale                              43.1
# 29          South Lawndale                              30.7
# ..                     ...                               ...
# 48                Roseland                              19.8
# 49                 Pullman                              21.6
# 50           South Deering                              29.2
# 51               East Side                              19.2
# 52            West Pullman                              25.9
# 53               Riverdale                              56.5
# 54               Hegewisch                              17.1
# 55          Garfield Ridge                               8.8
# 56          Archer Heights                              14.1
# 57           Brighton Park                              23.6
# 58           McKinley Park                              18.7
# 59              Bridgeport                              18.9
# 60                New City                              29.0
# 61             West Elsdon                              15.6
# 62               Gage Park                              23.4
# 63                Clearing                               8.9
# 64               West Lawn                              14.9
# 65            Chicago Lawn                              27.9
# 66          West Englewood                              34.4
# 67               Englewood                              46.6
# 68  Greater Grand Crossing                              29.6
# 69                 Ashburn                              10.4
# 70          Auburn Gresham                              27.6
# 71                 Beverly                               5.1
# 72       Washington Height                              16.9
# 73         Mount Greenwood                               3.4
# 74             Morgan Park                              13.2
# 75                  O'Hare                              15.4
# 76               Edgewater                              18.2
# 77                 CHICAGO                              19.7
#
#     PERCENT AGED 16+ UNEMPLOYED  PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 0                           8.7                                          18.2
# 1                           8.8                                          20.8
# 2                           8.9                                          11.8
# 3                           8.2                                          13.4
# 4                           5.2                                           4.5
# 5                           4.7                                           2.6
# 6                           5.1                                           3.6
# 7                           7.0                                           2.5
# 8                           6.5                                           7.4
# 9                           9.0                                          11.5
# 10                         12.4                                          13.4
# 11                          6.8                                           4.9
# 12                          9.9                                          14.4
# 13                         10.0                                          32.9
# 14                         12.6                                          19.3
# 15                         10.0                                          22.4
# 16                         10.0                                          16.2
# 17                         13.8                                          23.5
# 18                         14.6                                          37.3
# 19                         13.1                                          41.6
# 20                          9.2                                          24.7
# 21                          8.2                                          14.8
# 22                         17.3                                          35.4
# 23                          6.6                                          12.9
# 24                         22.6                                          24.4
# 25                         25.8                                          24.5
# 26                         19.6                                          21.3
# 27                         10.7                                           9.6
# 28                         21.2                                          27.6
# 29                         15.8                                          54.8
# ..                          ...                                           ...
# 48                         20.3                                          16.9
# 49                         22.8                                          13.1
# 50                         16.3                                          21.0
# 51                         12.1                                          31.9
# 52                         19.4                                          20.5
# 53                         34.6                                          27.5
# 54                          9.6                                          19.2
# 55                         11.3                                          19.3
# 56                         16.5                                          35.9
# 57                         13.9                                          45.1
# 58                         13.4                                          32.9
# 59                         13.7                                          22.2
# 60                         23.0                                          41.5
# 61                         16.7                                          37.0
# 62                         18.2                                          51.5
# 63                          9.5                                          18.8
# 64                          9.6                                          33.6
# 65                         17.1                                          31.2
# 66                         35.9                                          26.3
# 67                         28.0                                          28.5
# 68                         23.0                                          16.5
# 69                         11.7                                          17.7
# 70                         28.3                                          18.5
# 71                          8.0                                           3.7
# 72                         20.8                                          13.7
# 73                          8.7                                           4.3
# 74                         15.0                                          10.8
# 75                          7.1                                          10.9
# 76                          9.2                                           9.7
# 77                         12.9                                          19.5
#
#     PER CAPITA INCOME  HARDSHIP INDEX
# 0               23939            39.0
# 1               23040            46.0
# 2               35787            20.0
# 3               37524            17.0
# 4               57123             6.0
# 5               60058             5.0
# 6               71551             2.0
# 7               88669             1.0
# 8               40959             8.0
# 9               32875            21.0
# 10              27751            25.0
# 11              44164            11.0
# 12              26576            33.0
# 13              21323            53.0
# 14              24336            35.0
# 15              27249            34.0
# 16              26282            28.0
# 17              22014            50.0
# 18              15461            70.0
# 19              15089            71.0
# 20              20039            42.0
# 21              31908            23.0
# 22              13781            85.0
# 23              43198            10.0
# 24              15957            73.0
# 25              10934            92.0
# 26              12961            83.0
# 27              44689            15.0
# 28              12034            87.0
# 29              10402            96.0
# ..                ...             ...
# 48              17949            52.0
# 49              20588            51.0
# 50              14685            65.0
# 51              17104            64.0
# 52              16563            62.0
# 53               8201            98.0
# 54              22677            44.0
# 55              26353            32.0
# 56              16134            67.0
# 57              13089            84.0
# 58              16954            61.0
# 59              22694            43.0
# 60              12765            91.0
# 61              15754            69.0
# 62              12171            93.0
# 63              25113            29.0
# 64              16907            56.0
# 65              13231            80.0
# 66              11317            89.0
# 67              11888            94.0
# 68              17285            66.0
# 69              23482            37.0
# 70              15528            74.0
# 71              39523            12.0
# 72              19713            48.0
# 73              34381            16.0
# 74              27149            30.0
# 75              25828            24.0
# 76              33385            19.0
# 77              28202             NaN
#
# [78 rows x 6 columns]

# %% [markdown]
# ### Challenge 8: Using new subset from Challenge 7, create another new subset without 'COMMUNITY AREA NAME' (hint: delete column)

# %%
sub_poverty=sub_poverty.drop(columns=['COMMUNITY AREA NAME'])
sub_poverty
# Out:
#     PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 0                               23.6                          8.7
# 1                               17.2                          8.8
# 2                               24.0                          8.9
# 3                               10.9                          8.2
# 4                                7.5                          5.2
# 5                               11.4                          4.7
# 6                               12.3                          5.1
# 7                               12.9                          7.0
# 8                                3.3                          6.5
# 9                                5.4                          9.0
# 10                               8.6                         12.4
# 11                               7.5                          6.8
# 12                              13.2                          9.9
# 13                              19.2                         10.0
# 14                              11.6                         12.6
# 15                              13.1                         10.0
# 16                              10.6                         10.0
# 17                              15.3                         13.8
# 18                              18.7                         14.6
# 19                              20.5                         13.1
# 20                              15.3                          9.2
# 21                              16.8                          8.2
# 22                              33.9                         17.3
# 23                              14.7                          6.6
# 24                              28.6                         22.6
# 25                              41.7                         25.8
# 26                              42.4                         19.6
# 27                              20.6                         10.7
# 28                              43.1                         21.2
# 29                              30.7                         15.8
# ..                               ...                          ...
# 48                              19.8                         20.3
# 49                              21.6                         22.8
# 50                              29.2                         16.3
# 51                              19.2                         12.1
# 52                              25.9                         19.4
# 53                              56.5                         34.6
# 54                              17.1                          9.6
# 55                               8.8                         11.3
# 56                              14.1                         16.5
# 57                              23.6                         13.9
# 58                              18.7                         13.4
# 59                              18.9                         13.7
# 60                              29.0                         23.0
# 61                              15.6                         16.7
# 62                              23.4                         18.2
# 63                               8.9                          9.5
# 64                              14.9                          9.6
# 65                              27.9                         17.1
# 66                              34.4                         35.9
# 67                              46.6                         28.0
# 68                              29.6                         23.0
# 69                              10.4                         11.7
# 70                              27.6                         28.3
# 71                               5.1                          8.0
# 72                              16.9                         20.8
# 73                               3.4                          8.7
# 74                              13.2                         15.0
# 75                              15.4                          7.1
# 76                              18.2                          9.2
# 77                              19.7                         12.9
#
#     PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  PER CAPITA INCOME  \
# 0                                           18.2              23939
# 1                                           20.8              23040
# 2                                           11.8              35787
# 3                                           13.4              37524
# 4                                            4.5              57123
# 5                                            2.6              60058
# 6                                            3.6              71551
# 7                                            2.5              88669
# 8                                            7.4              40959
# 9                                           11.5              32875
# 10                                          13.4              27751
# 11                                           4.9              44164
# 12                                          14.4              26576
# 13                                          32.9              21323
# 14                                          19.3              24336
# 15                                          22.4              27249
# 16                                          16.2              26282
# 17                                          23.5              22014
# 18                                          37.3              15461
# 19                                          41.6              15089
# 20                                          24.7              20039
# 21                                          14.8              31908
# 22                                          35.4              13781
# 23                                          12.9              43198
# 24                                          24.4              15957
# 25                                          24.5              10934
# 26                                          21.3              12961
# 27                                           9.6              44689
# 28                                          27.6              12034
# 29                                          54.8              10402
# ..                                           ...                ...
# 48                                          16.9              17949
# 49                                          13.1              20588
# 50                                          21.0              14685
# 51                                          31.9              17104
# 52                                          20.5              16563
# 53                                          27.5               8201
# 54                                          19.2              22677
# 55                                          19.3              26353
# 56                                          35.9              16134
# 57                                          45.1              13089
# 58                                          32.9              16954
# 59                                          22.2              22694
# 60                                          41.5              12765
# 61                                          37.0              15754
# 62                                          51.5              12171
# 63                                          18.8              25113
# 64                                          33.6              16907
# 65                                          31.2              13231
# 66                                          26.3              11317
# 67                                          28.5              11888
# 68                                          16.5              17285
# 69                                          17.7              23482
# 70                                          18.5              15528
# 71                                           3.7              39523
# 72                                          13.7              19713
# 73                                           4.3              34381
# 74                                          10.8              27149
# 75                                          10.9              25828
# 76                                           9.7              33385
# 77                                          19.5              28202
#
#     HARDSHIP INDEX
# 0             39.0
# 1             46.0
# 2             20.0
# 3             17.0
# 4              6.0
# 5              5.0
# 6              2.0
# 7              1.0
# 8              8.0
# 9             21.0
# 10            25.0
# 11            11.0
# 12            33.0
# 13            53.0
# 14            35.0
# 15            34.0
# 16            28.0
# 17            50.0
# 18            70.0
# 19            71.0
# 20            42.0
# 21            23.0
# 22            85.0
# 23            10.0
# 24            73.0
# 25            92.0
# 26            83.0
# 27            15.0
# 28            87.0
# 29            96.0
# ..             ...
# 48            52.0
# 49            51.0
# 50            65.0
# 51            64.0
# 52            62.0
# 53            98.0
# 54            44.0
# 55            32.0
# 56            67.0
# 57            84.0
# 58            61.0
# 59            43.0
# 60            91.0
# 61            69.0
# 62            93.0
# 63            29.0
# 64            56.0
# 65            80.0
# 66            89.0
# 67            94.0
# 68            66.0
# 69            37.0
# 70            74.0
# 71            12.0
# 72            48.0
# 73            16.0
# 74            30.0
# 75            24.0
# 76            19.0
# 77             NaN
#
# [78 rows x 5 columns]

# %% [markdown]
# ### Challenge 9: using new subset in Challenge 8, plot scatter plot using 'HARDSHIP INDEX' (Y) and 'PER CAPITA INCOME' (X)

# %%
x = sub_poverty['PER CAPITA INCOME']
y = sub_poverty['HARDSHIP INDEX']

plt.scatter(x, y,  alpha=0.5)
plt.show()

# %% [markdown]
# ### Challenge 10: using new subset in Challenge 8, conduct correlation coefficient table

# %%
sub_poverty.corr()
# Out:
#                                               PERCENT HOUSEHOLDS BELOW POVERTY  \
# PERCENT HOUSEHOLDS BELOW POVERTY                                      1.000000
# PERCENT AGED 16+ UNEMPLOYED                                           0.800084
# PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA                          0.424294
# PER CAPITA INCOME                                                    -0.567025
# HARDSHIP INDEX                                                        0.803267
#
#                                               PERCENT AGED 16+ UNEMPLOYED  \
# PERCENT HOUSEHOLDS BELOW POVERTY                                 0.800084
# PERCENT AGED 16+ UNEMPLOYED                                      1.000000
# PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA                     0.355518
# PER CAPITA INCOME                                               -0.656619
# HARDSHIP INDEX                                                   0.792294
#
#                                               PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# PERCENT HOUSEHOLDS BELOW POVERTY                                                  0.424294
# PERCENT AGED 16+ UNEMPLOYED                                                       0.355518
# PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA                                      1.000000
# PER CAPITA INCOME                                                                -0.709770
# HARDSHIP INDEX                                                                    0.802538
#
#                                               PER CAPITA INCOME  \
# PERCENT HOUSEHOLDS BELOW POVERTY                      -0.567025
# PERCENT AGED 16+ UNEMPLOYED                           -0.656619
# PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA          -0.709770
# PER CAPITA INCOME                                      1.000000
# HARDSHIP INDEX                                        -0.849167
#
#                                               HARDSHIP INDEX
# PERCENT HOUSEHOLDS BELOW POVERTY                    0.803267
# PERCENT AGED 16+ UNEMPLOYED                         0.792294
# PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA        0.802538
# PER CAPITA INCOME                                  -0.849167
# HARDSHIP INDEX                                      1.000000

# %% [markdown]
# ### Challenge 11: using new subset in Challenge 8, construct Correlation plot (heatmap) using seaborn

# %%
Var_Corr = sub_poverty.corr()
sns.heatmap(Var_Corr, xticklabels=Var_Corr.columns, yticklabels=Var_Corr.columns, annot=True)

# %% [markdown]
# ## Linear Regression Example

# %%
#subset all independent variables  
import statsmodels.api as sm
indvar = sub_poverty[['PER CAPITA INCOME']]
dvar = sub_poverty[['HARDSHIP INDEX']]
X = indvar
Y = dvar
X = sm.add_constant(X)
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
model = sm.OLS(Y, X, missing='drop').fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         HARDSHIP INDEX   R-squared:                       0.721
# Model:                            OLS   Adj. R-squared:                  0.717
# Method:                 Least Squares   F-statistic:                     193.9
# Date:                Mon, 12 Aug 2019   Prob (F-statistic):           1.73e-22
# Time:                        11:34:56   Log-Likelihood:                -318.05
# No. Observations:                  77   AIC:                             640.1
# Df Residuals:                      75   BIC:                             644.8
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                90.2306      3.402     26.522      0.000      83.453      97.008
# PER CAPITA INCOME    -0.0016      0.000    -13.925      0.000      -0.002      -0.001
# ==============================================================================
# Omnibus:                        5.349   Durbin-Watson:                   1.376
# Prob(Omnibus):                  0.069   Jarque-Bera (JB):                4.906
# Skew:                           0.615   Prob(JB):                       0.0860
# Kurtosis:                       3.125   Cond. No.                     5.82e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.82e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
